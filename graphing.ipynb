# %%
# %matplotlib inline
import fiona
from shapely.geometry import Point, shape
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from bokeh.io import show, output_file
from bokeh.plotting import figure
from bokeh.palettes import PuOr, Viridis6
from bokeh.models import (
    GMapPlot, GMapOptions, ColumnDataSource, Patches, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool,
    LinearColorMapper, HoverTool
    )
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
districts = []
lng_ls = []
lat_ls = []
with fiona.open("Neighborhoods/nyc.shp") as sf:
    for s in sf:
        lng = []
        lat = []
        coords = s['geometry']['coordinates']
        n = len(coords)
        if s['geometry']['type'] == 'Polygon':
            lng += [x[0] for x in coords[0]]
            lat += [x[1] for x in coords[0]]
        else:
            for i, patch in enumerate(coords): 
                lng += [x[0] for x in patch[0]]
                lat += [x[1] for x in patch[0]]
                #if i < n - 1: # separate multi polygon by 'NaN'
                lng.append(np.nan)
                lat.append(np.nan)
        lng_ls.append(lng)
        lat_ls.append(lat)
        districts.append(s['properties']['ntaname'])

# %%
duration = [np.random.uniform(1200,2400) for x in districts]
duration_tool = ["%.1f min" %(s/60) for s in duration]

# %%
duration_tool[:5]
# Out:
# ['25.2 min', '22.4 min', '36.7 min', '21.4 min', '34.6 min']

# %%
print len(lng_ls), len(lat_ls), len(districts), len(duration)
# Out:
# 195 195 195 195

# %%
print lng_ls
# Out:
# [[-73.97604935657381, -73.97716511994669, -73.97699848928193, -73.9768496430902, -73.97669604371914, -73.97657775689153, -73.9765146210018, -73.97644970441577, -73.97623453682755, -73.97726150032737, -73.97719665645002, -73.97710959292857, -73.97694382374165, -73.9768346520651, -73.97675209645574, -73.97656583927008, -73.97695070814679, -73.97705352864567, -73.97539380523678, -73.97682433557303, -73.97752301889588, -73.97785009338085, -73.97562954146068, -73.97537335532121, -73.97544276701358, -73.97548096980243, -73.97444328442452, -73.97335879350746, -73.97290326943272, -73.97399319461375, -73.97517176991693, -73.97497264664409, -73.97489295756654, -73.97477657974535, -73.97520829413772, -73.9774081645899, -73.97963821772845, -73.98003930358351, -73.9808791278371, -73.98186818243128, -73.9840679176659, -73.98627524709667, -73.98569357824182, -73.9878509553418, -73.99009356051286, -73.99254973616581, -73.99398197149371, -73.99432497413301, -73.99489280561376, -73.99473485679263, -73.99464972974172, -73.99507814869848, -73.99678847531307, -73.99687778353756, -73.99701633648009, -73.9972406703973, -73.99811614328407, -74.00031369476771, -74.00251454806298, -74.00222793396246, -74.00193011441125, -74.00306154030783, -74.00368597245085, -74.00413727968571, -74.00633870652992, -74.00702302486354, -74.00680677851517, -74.00661914959808, -74.00630615538647
.63895767781394), (-74.0020907543513, 40.6392252543082), (-74.00150771254626, 40.6397849620733), (-74.00092541773434, 40.64034590202875), (-74.00066078180645, 40.64059930920131), (-74.00034122066634, 40.64090531617318), (-73.99975690844894, 40.64146715044591), (-73.9991756471891, 40.642025442029095), (-73.99697357409411, 40.64069410459458), (-73.99551033762245, 40.63980966713005), (-73.99479539539372, 40.640288487384396), (-73.99433124126968, 40.6406002879529), (-73.99407692009133, 40.64077040176035), (-73.99336253671026, 40.64124779897801), (-73.9926445605762, 40.641728290946446), (-73.9919281237555 ...

# %%
with fiona.open("Neighborhoods/nyc.shp") as sf:
    for i,s in enumerate(sf):
        print i, len(s['geometry']['coordinates']), s['properties']['ntaname']
# Out:
# 0 1 Borough Park
# 1 1 East Flushing
# 2 1 Auburndale
# 3 1 Murray Hill
# 4 1 East Elmhurst
# 5 1 Morrisania-Melrose
# 6 1 Rikers Island
# 7 1 Hollis
# 8 1 Manhattanville
# 9 1 Springfield Gardens North
# 10 1 Old Astoria
# 11 1 Bayside-Bayside Hills
# 12 1 Pomonok-Flushing Heights-Hillcrest
# 13 1 Clinton
# 14 1 Homecrest
# 15 1 Westchester-Unionport
# 16 1 Fresh Meadows-Utopia
# 17 3 park-cemetery-etc-Staten Island
# 18 1 Rego Park
# 19 1 Midtown-Midtown South
# 20 3 Turtle Bay-East Midtown
# 21 1 Ft. Totten-Bay Terrace-Clearview
# 22 1 St. Albans
# 23 1 Richmond Hill
# 24 2 Corona
# 25 1 South Ozone Park
# 26 1 Jamaica Estates-Holliswood
# 27 1 Madison
# 28 1 Windsor Terrace
# 29 1 Kensington-Ocean Parkway
# 30 1 Erasmus
# 31 1 Longwood
# 32 1 Clinton Hill
# 33 3 Schuylerville-Throgs Neck-Edgewater Park
# 34 1 Whitestone
# 35 1 Kew Gardens Hills
# 36 8 Battery Park City-Lower Manhattan
# 37 1 North Corona
# 38 1 Bath Beach
# 39 1 Bensonhurst West
# 40 1 Greenpoint
# 41 1 Great Kills
# 42 1 Maspeth
# 43 1 Sheepshead Bay-Gerritsen Beach-Manhattan Beach
# 44 1 Briarwood-Jamaica Hills
# 45 1 Jamaica
# 46 1 New Dorp-Midland Beach
# 47 1 Woodside
# 48 1 Baisley Park
# 49 1 South Jamaica
# 50 8 Pelham Bay-Country Club-City Island
# 51 1 Sunset Park East
# 52 1 Cambria Heights
# 53 1 Astoria
# 54 1 Queens Village
# 55 1 Laurelton
# 56 1 Georgetown-Marine Park-Bergen Beach-Mill Basin
# 57 1 Midwood
# 58 1 Gravesend
# 59 1 Bensonhurst East
# 60 2 Mariner's Harbor-Arlington-Port Ivory-Graniteville
# 61 8 Port Richmond
# 62 1 Brighton Beach
# 63 1 Arden Heights
# 64 1 Rossville-Woodrow
# 65 1 Flatlands
# 66 2 Yorkville
# 67 1 East New York (Pennsylvania Ave)
# 68 1 Ozone Park
# 69 1 Prospect Lefferts Gardens-Wingate
# 70 1 East Williamsburg
# 71 1 Williamsburg
# 72 1 Bedford
# 73 1 Brownsville
# 74 2 Murray Hill-Kips Bay
# 75 1 Stuyvesant Heights
# 76 1 Ocean Hill
# 77 1 Crown Heights North
# 78 1 Gramercy
# 79 1 Crown Heights South
# 80 1 Rugby-Remsen Village
# 81 1 Bronxdale
# 82 1 Williamsbridge-Olinville
# 83 1 Eastchester-Edenwald-Baychester
# 84 1 Allerton-Pelham Gardens
# 85 2 Starrett City
# 86 1 Stapleton-Rosebank
# 87 1 Hunters Point-Sunnyside-West Maspeth
# 88 1 Queensboro Hill
# 89 1 Hudson Yards-Chelsea-Flatiron-Union Square
# 90 1 West Village
# 91 2 East Flatbush-Farragut
# 92 1 Westerleigh
# 93 1 Annadale-Huguenot-Prince's Bay-Eltingville
# 94 1 Charleston-Richmond Valley-Tottenville
# 95 1 Douglas Manor-Douglaston-Little Neck
# 96 1 Bushwick South
# 97 1 Bushwick North
# 98 1 Ridgewood
# 99 1 Bellerose
# 100 1 Glen Oaks-Floral Park-New Hyde Park
# 101 1 Mount Hope
# 102 1 Ocean Parkway South
# 103 1 Flushing
# 104 1 West New Brighton-New Brighton-St. George
# 105 1 SoHo-TriBeCa-Civic Center-Little Italy
# 106 1 Chinatown
# 107 2 Stuyvesant Town-Cooper Village
# 108 1 Grasmere-Arrochar-Ft. Wadsworth
# 109 1 Old Town-Dongan Hills-South Beach
# 110 1 North Riverdale-Fieldston-Riverdale
# 111 1 Spuyten Duyvil-Kingsbridge
# 112 1 Flatbush
# 113 1 Woodlawn-Wakefield
# 114 1 Oakwood-Oakwood Beach
# 115 1 Kingsbridge Heights
# 116 1 University Heights-Morris Heights
# 117 1 Melrose South-Mott Haven North
# 118 3 Breezy Point-Belle Harbor-Rockaway Park-Broad Channel
# 119 1 Hammels-Arverne-Edgemere
# 120 1 East Tremont
# 121 1 Van Nest-Morris Park-Westchester Square
# 122 1 Forest Hills
# 123 1 Kew Gardens
# 124 1 Fort Greene
# 125 1 Claremont-Bathgate
# 126 1 Fordham South
# 127 5 East Harlem North
# 128 2 Lenox Hill-Roosevelt Island
# 129 1 Queensbridge-Ravenswood-Long Island City
# 130 3 Mott Haven-Port Morris
# 131 1 Steinway
# 132 1 Oakland Gardens
# 133 2 College Point
# 134 1 East Concourse-Concourse Village
# 135 1 Pelham Parkway
# 136 1 DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
# 137 1 West Farms-Bronx River
# 138 1 Parkchester
# 139 1 Soundview-Bruckner
# 140 1 Bedford Park-Fordham North
# 141 1 Norwood
# 142 1 Hunts Point
# 143 1 Crotona Park East
# 144 1 Grymes Hill-Clifton-Fox Hills
# 145 1 New Brighton-Silver Lake
# 146 1 Co-op City
# 147 1 Prospect Heights
# 148 1 Dyker Heights
# 149 1 Bay Ridge
# 150 1 Far Rockaway-Bayswater
# 151 1 Elmhurst
# 152 1 Elmhurst-Maspeth
# 153 1 Springfield Gardens South-Brookville
# 154 3 Lindenwood-Howard Beach
# 155 1 Rosedale
# 156 1 Jackson Heights
# 157 7 Airport
# 158 1 Woodhaven
# 159 1 Brooklyn Heights-Cobble Hill
# 160 1 Carroll Gardens-Columbia Street-Red Hook
# 161 1 North Side-South Side
# 162 1 Hamilton Heights
# 163 1 Central Harlem North-Polo Grounds
# 164 1 New Springville-Bloomfield-Travis
# 165 1 Todt Hill-Emerson Hill-Heartland Village-Lighthouse Hill
# 166 1 Seagate-Coney Island
# 167 1 West Brighton
# 168 1 East New York
# 169 2 Canarsie
# 170 1 Glendale
# 171 1 Middle Village
# 172 3 Marble Hill-Inwood
# 173 1 Belmont
# 174 1 Central Harlem South
# 175 1 Park Slope-Gowanus
# 176 1 Sunset Park West
# 177 1 Cypress Hills-City Line
# 178 1 Upper East Side-Carnegie Hill
# 179 1 Lincoln Square
# 180 1 East Harlem South
# 181 36 park-cemetery-etc-Brooklyn
# 182 33 park-cemetery-etc-Queens
# 183 15 park-cemetery-etc-Manhattan
# 184 1 Van Cortlandt Village
# 185 1 Morningside Heights
# 186 1 Upper West Side
# 187 1 East Village
# 188 6 Lower East Side
# 189 1 Washington Heights North
# 190 1 Washington Heights South
# 191 1 Highbridge
# 192 1 West Concourse
# 193 3 Soundview-Castle Hill-Clason Point-Harding Park
# 194 19 park-cemetery-etc-Bronx

# %%
def plot_map(fname):
    map_options = GMapOptions(lat=40.75, lng=-73.9, map_type='roadmap', zoom=11)
    API_KEY = 'AIzaSyC-4SnwvK3u2CR-zh-4zl7J_msCmDfq_Sg'
    #palette = sns.color_palette("hls", n).as_hex()
    color_mapper = LinearColorMapper(palette = PuOr[11])

    plot = GMapPlot(x_range=DataRange1d(),
                    y_range=DataRange1d(),
                    map_options=map_options,
                    api_key=API_KEY,
                    plot_width=1000,
                    plot_height=1000,)

    source = ColumnDataSource(data=dict(
                                    lat = lat_ls, 
                                    lng = lng_ls,
                                    grp = districts,
                                    dur = duration,
                                    durt = duration_tool,
        ))
    
    patches = Patches(xs='lng', ys='lat',
                    fill_color={'field': 'dur', 'transform': color_mapper}, 
                    fill_alpha=0.7, line_color="blue", line_width=0.5)
    plot.add_glyph(source, patches, name='patches')
    hover = HoverTool(names=['patches'],
                      tooltips=[
                        ("Neighborhood", "@grp"),
                        ("Trip Duration", "@durt"),
                ])
    plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool(), hover)
    output_file(fname)
    return plot

# %%
p = plot_map('test.html')
show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'test.html' already exists, will be overwritten.
